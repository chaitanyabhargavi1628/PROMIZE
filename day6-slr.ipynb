# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\Ramesh'

# %%
match=pd.read_csv(r'C:\Users\Ramesh\Downloads\scorecard2019.csv')
match.head()
# Out:
#        Batsmen  Runs  Balls  Fours  sixes
# 0    DA Warner   692    481    688     51
# 1  Q de Kock †   529    398    625     41
# 2     S Dhawan   521    384    598     61
# 3   AD Russell   510    249    369     33
# 4    RR Pant †   488    300    523     37

# %%
match.iloc[:,:3]
# Out:
#                Batsmen  Runs  Balls
# 0            DA Warner   692    481
# 1          Q de Kock †   529    398
# 2             S Dhawan   521    384
# 3           AD Russell   510    249
# 4            RR Pant †   488    300
# 5          SS Iyer (c)   463    386
# 6          V Kohli (c)   458    316
# 7        JM Bairstow †   445    283
# 8       AB de Villiers   442    287
# 9             SA Yadav   424    324
# 10      MS Dhoni (c) †   416    309
# 11            CH Gayle   411    272
# 12             CA Lynn   405    290
# 13       RG Sharma (c)   405    315
# 14           HH Pandya   402    210
# 15           SR Watson   398    312
# 16        F du Plessis   396    321
# 17            SK Raina   368    297
# 18             PP Shaw   353    264
# 19              N Rana   344    235
# 20          PA Patel †   344    233
# 21           MK Pandey   344    263
# 22          MA Agarwal   332    234
# 23          KL Rahul †   325    246
# 24        Shubman Gill   296    238
# 25          RV Uthappa   282    245
# 26           AT Rayudu   282    300
# 27            KL Rahul   268    192
# 28    KD Karthik (c) †   253    173
# 29           V Shankar   244    193
# ..                 ...   ...    ...
# 126          GH Vihari     4      8
# 127         Avesh Khan     4      3
# 128         GC Viljoen     3      7
# 129          AJ Turner     3     10
# 130           VR Aaron     3      7
# 131           M Ashwin     3      5
# 132            BB Sran     3      3
# 133        B Kumar (c)     2      6
# 134           NA Saini     2      4
# 135    Harbhajan Singh     1      3
# 136  Washington Sundar     1      3
# 137     Mohammed Shami     1      2
# 138         JD Unadkat     1      3
# 139       Basil Thampi     1      1
# 140          HF Gurney     1      5
# 141          MM Sharma     0      2
# 142   Mujeeb Ur Rahman     0      4
# 143             AJ Tye     0      2
# 144      SW Billings †     0      4
# 145           HV Patel     0      2
# 146        AT Rayudu †     0      3
# 147             S Kaul     0      1
# 148          JJ Bumrah     0      1
# 149           DW Steyn     0      0
# 150           KK Ahmed     0      1
# 151        Imran Tahir     0      0
# 152      Y Prithvi Raj     0      1
# 153           JL Denly     0      1
# 154  M Prasidh Krishna     0      2
# 155       S Lamichhane     0      1
#
# [156 rows x 3 columns]

# %%
match.head()
# Out:
#        Batsmen  Runs  Balls  Fours  sixes
# 0    DA Warner   692    481    688     51
# 1  Q de Kock †   529    398    625     41
# 2     S Dhawan   521    384    598     61
# 3   AD Russell   510    249    369     33
# 4    RR Pant †   488    300    523     37

# %%
k=match.drop(columns=['Batsmen','Fours','sixes'])

# %%
k.head()
# Out:
#    Runs  Balls
# 0   692    481
# 1   529    398
# 2   521    384
# 3   510    249
# 4   488    300

# %%
import seaborn as sns
sns.pairplot(k.iloc[:,:])

# %%
x= k.iloc[:,:-1]
print(x)
# Out:
#      Runs
# 0     692
# 1     529
# 2     521
# 3     510
# 4     488
# 5     463
# 6     458
# 7     445
# 8     442
# 9     424
# 10    416
# 11    411
# 12    405
# 13    405
# 14    402
# 15    398
# 16    396
# 17    368
# 18    353
# 19    344
# 20    344
# 21    344
# 22    332
# 23    325
# 24    296
# 25    282
# 26    282
# 27    268
# 28    253
# 29    244
# ..    ...
# 126     4
# 127     4
# 128     3
# 129     3
# 130     3
# 131     3
# 132     3
# 133     2
# 134     2
# 135     1
# 136     1
# 137     1
# 138     1
# 139     1
# 140     1
# 141     0
# 142     0
# 143     0
# 144     0
# 145     0
# 146     0
# 147     0
# 148     0
# 149     0
# 150     0
# 151     0
# 152     0
# 153     0
# 154     0
# 155     0
#
# [156 rows x 1 columns]

# %%
y=k.iloc[:,1:]
y.head()
# Out:
#    Balls
# 0    481
# 1    398
# 2    384
# 3    249
# 4    300

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from  matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
data=LinearRegression()
data.fit(x_train,y_train)
plt.scatter(x_train,y_train, color= 'green')

# %%
y_pred=data.predict(x_test)
y_pred
# Out:
# array([[202.20364658],
#        [ 81.7870725 ],
#        [137.79478137],
#        [  9.67714733],
#        [212.00499563],
#        [316.3193534 ],
#        [113.9915051 ],
#        [ 11.07734005],
#        [  5.47656916],
#        [132.89410685],
#        [ 17.3782073 ],
#        [ 90.88832519],
#        [ 11.07734005],
#        [  8.97705097],
#        [ 75.48620525],
#        [  4.7764728 ],
#        [146.89603406],
#        [  8.97705097],
#        [116.79189055],
#        [  6.87676189],
#        [  4.7764728 ],
#        [314.21906432],
#        [  5.47656916],
#        [ 71.28562709],
#        [ 10.37724369],
#        [  4.7764728 ],
#        [ 22.27888183],
#        [ 63.58456712],
#        [ 27.17955635],
#        [ 15.27791822],
#        [282.01463172],
#        [245.60962095]])

# %%
y_pred==y_test
# Out:
#      Balls
# 26   False
# 54   False
# 37   False
# 112  False
# 24   False
# 7    False
# 45   False
# 107  False
# 137  False
# 40   False
# 90   False
# 51   False
# 108  False
# 119  False
# 56   False
# 147  False
# 33   False
# 118  False
# 44   False
# 128  False
# 145  False
# 8    False
# 139  False
# 59   False
# 111  False
# 152  False
# 85   False
# 62   False
# 83   False
# 94   False
# 16   False
# 19   False

# %%
np.mean(y_pred)
# Out:
# 86.81901509557325

# %%
np.mean(y_test)
# Out:
# Balls    91.0
# dtype: float64

# %%
plt.scatter(x_train, y_train, color = "red")
plt.plot(x_train, data.predict(x_train))
plt.title('Runs-Balls')
plt.xlabel('Runs')
plt.ylabel('Balls')
# Out:
# Text(0,0.5,'Balls')

# %%
plt.plot(x_train, data.predict(x_train))
plt.scatter(x_test, y_test, color = "cyan")

# %%
plt.scatter(y_pred, y_test)
