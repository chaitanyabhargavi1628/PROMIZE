# %% [markdown]
# 1 . Draw a pie plot based on number of wins for each team
#
# 2. Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4,5]
y=[3,4,5,6,7]
df1=np.random.rand(50)
df2=np.random.rand(50)

t = np.arange(50)
plt.scatter(df1, df2, c=t, edgecolor = 'k',cmap ='summer',alpha= 0.5)

# %%
x=[2.5,9.5,4.5,5.5,6.5,7.5,8.5]
y=[2,3,4,5,6,7,9,]
plt.scatter(x,y,color='orange')
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.title('plot')
plt.show()


plt.barh(x,y,color='red')
# Out:
# <BarContainer object of 7 artists>

# %%
names=['seetha','geetha','sheela','maala']
java=[75,80,88,97]
python=[89,90,89,97]
c=[85,89,93,76]
width=0.3
plt.bar(names,java,color='orange',width=0.4,label='bar1')
plt.bar(names,python,color=['green','red'],width=0.3,label='bar2')
# Out:
# <BarContainer object of 4 artists>

# %%
subjects=['english','maths','social','chemistry']
marks=[95,97,85,88]
plt.pie(marks,labels=subjects, shadow = True , startangle = 90,autopct = '%1.1f%%',labeldistance=1.2 )
plt.legend(loc = "best")

# %%
ax = plt.axes(projection='3d')# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#      62     try:
# ---> 63         return projection_registry.get_projection_class(projection)
#      64     except KeyError:
#
# D:\anaconda\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(self, name)
#      28         """
# ---> 29         return self._all_projection_types[name]
#      30
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-58013edfd000> in <module>()
# ----> 1 ax = plt.axes(projection='3d')# Data for a three-dimensional line
#       2 zline = np.linspace(0, 15, 1000)
#       3 xline = np.sin(zline)
#       4 yline = np.cos(zline)
# ...
